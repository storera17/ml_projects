# %% [markdown]
# <div
#      style="padding: 20px;
#             color: white;
#             font-size: 250%;
#             text-align: center;
#             display: fill;
#             border-radius: 5px;
#             background-color: #2a2a9fab;
#             overflow: hidden;
#             font-weight: 700;
#             border: 5px solid #bebe0d;"
#      >
# Data Wrangling in Python
# </div>

# %% [markdown]
# <div style="color:white;display:fill;
#             background-color:#2a2a9fab;font-size:200%;">
#     <p style="padding: 4px;color:white;"><b>Imports</b></p>
# </div>

# %%
#Import Python Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <div style="color:white;display:fill;
#             background-color:#2a2a9fab;font-size:200%;">
#     <p style="padding: 4px;color:white;"><b>Data Exploration</b></p>
# </div>
